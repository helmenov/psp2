# %% [markdown]
# # Numpy

# %%
## テンソル

Pythonでは，値の集合を「コンテナ」と呼び，代表的なものとして

- リスト(List): [1, 'two', [3], 3.14]
    - タプル(Tuple): (1, 'two', [3], 3.14)
    - 文字列(Str): 'aa83988848'
- 集合(Set): {1, 'two', [3], 3.14}
    - 辞書(Dict): {'v1':1, 'v2':'two', 'v3':[3], 'v4':3.14}

があります．ただし，これらは値を保存するにはよいですが，表計算のようにまとめて計算するようにはなっていません．

まとめて計算できるような変数としたものが，ベクトル，行列，テンソルです．線形代数で学んでいますね．

線形代数の世界では，

- スカラー　：値１つ
- ベクトル : 複数の値が縦1列，もしくは横1行に並んだもの
- 行列：複数の値が縦横に並んだもの

と思いますが，NumPyの世界では，これらはすべて行列(2階テンソル)と呼んでいます．

- スカラーは，(1,1)行列
- ベクトルは，(M,1)行列や(1,N)行列
- 行列は，(M,N)行列

のように，変数の大きさが，縦と横の**2つ**の整数値で表されるため，**2**階です．

一般化したK階テンソルは，K個の整数で大きさが表される変数です．

import numpy as np

a0 = np.array(1)
print(a.shape)

a1 = np.array([2])

b1 = np.array([1,2])

a2 = np.array([[3]])

b2 = np.array([[1,2]])

c2 = np.array([[1],[2]])
